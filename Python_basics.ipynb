# %% [markdown]
# <a href="https://colab.research.google.com/github/NishaDee/Git-GitHub-Project/blob/main/Python_basics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Guess the Number is a single-player game where the player is prompted to guess a number between 1 and 100. The game provides feedback to the player if their guess is too high or too low until they correctly guess the number.

# %%
print("Welcome to the Guess the Number game!")
print("I'm thinking of a number between 1 and 100. Can you guess what it is?")

# generate random number
import random
secret_number = random.randint(1, 100)

guess = None  # start with no guess

# loop until the player guesses correctly
while guess != secret_number:
    guess = input("Enter your guess: ")
    guess = int(guess)  # convert to integer

    if guess > secret_number:
        print("Your guess is too high. Guess again.")
    elif guess < secret_number:
        print("Your guess is too low. Guess again.")
    else:
        print("Congratulations! You guessed the number correctly!")
# Out:
# Welcome to the Guess the Number game!
# I'm thinking of a number between 1 and 100. Can you guess what it is?
# Enter your guess: 23
# Your guess is too high. Guess again.
# Enter your guess: 34
# Your guess is too high. Guess again.
# Enter your guess: 19
# Your guess is too high. Guess again.
# Enter your guess: 12
# Your guess is too high. Guess again.
# Enter your guess: 11
# Your guess is too high. Guess again.
# Enter your guess: 9
# Your guess is too high. Guess again.
# Enter your guess: 2
# Your guess is too low. Guess again.
# Enter your guess: 4
# Congratulations! You guessed the number correctly!
